# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('Airbnb_dataset.csv', sep=',')

# %%
df.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                 West Side Retreat  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long instant_bookable  ... Construction year  price  \
# 0  40.64749 -73.97237            False  ...            2020.0  $966
# 1  40.75362 -73.98377            False  ...            2007.0  $142
# 2  40.80902 -73.94190             True  ...            2005.0  $620
# 3  40.68514 -73.95976             True  ...            2005.0  $368
# 4  40.79851 -73.94399            False  ...            2009.0  $204
#
#    service fee minimum nights number of reviews  last review  \
# 0        $193            10.0               9.0   10/19/2021
# 1         $28            30.0              45.0    5/21/2022
# 2        $124             3.0               0.0          NaN
# 3         $74            30.0             270.0     5/7/2019
# 4         $41            10.0               9.0   11/19/2018
#
#    reviews per month review rate number  calculated host listings count  \
# 0               0.21                4.0                             6.0
# 1               0.38                4.0                             2.0
# 2                NaN                5.0                             1.0
# 3               4.64                4.0                             1.0
# 4               0.10                3.0                             1.0
#
#    availability 365
# 0             286.0
# 1             228.0
# 2             352.0
# 3             322.0
# 4             289.0
#
# [5 rows x 22 columns]

# %%
df.shape
# Out:
# (10000, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              10000 non-null  int64
#  1   NAME                            9988 non-null   object
#  2   host id                         10000 non-null  int64
#  3   host_identity_verified          9914 non-null   object
#  4   host name                       9977 non-null   object
#  5   neighbourhood group             9976 non-null   object
#  6   neighbourhood                   9986 non-null   object
#  7   lat                             9992 non-null   float64
#  8   long                            9992 non-null   float64
#  9   instant_bookable                9933 non-null   object
#  10  cancellation_policy             9959 non-null   object
#  11  room type                       10000 non-null  object
#  12  Construction year               9868 non-null   float64
#  13  price                           9971 non-null   object
#  14  service fee                     9969 non-null   object
#  15  minimum nights                  9908 non-null   float64
#  16  number of reviews               9989 non-null   float64
#  17  last review                     8630 non-null   object
#  18  reviews per month               8644 non-null   float64
#  19  review rate number              9908 non-null   float64
#  20  calculated host listings count  9977 non-null   float64
#  21  availability 365                9882 non-null   float64
# dtypes: float64(9), int64(2), object(11)
# memory usage: 1.7+ MB

# %%
df.describe()
# Out:
#                  id       host id          lat         long  \
# count  1.000000e+04  1.000000e+04  9992.000000  9992.000000
# mean   3.805425e+06  4.927253e+10    40.729018   -73.958945
# std    1.596639e+06  2.847096e+10     0.052331     0.036033
# min    1.001254e+06  1.316021e+08    40.508680   -74.239860
# 25%    2.426132e+06  2.468026e+10    40.688468   -73.983495
# 50%    3.806744e+06  4.906882e+10    40.722335   -73.958915
# 75%    5.187356e+06  7.398995e+10    40.764105   -73.943030
# max    6.567968e+06  9.873673e+10    40.908040   -73.729010
#
#        Construction year  minimum nights  number of reviews  \
# count        9868.000000     9908.000000        9989.000000
# mean         2012.405148        8.417642          44.749524
# std             5.776734       29.789385          68.181139
# min          2003.000000      -12.000000           0.000000
# 25%          2007.000000        2.000000           2.000000
# 50%          2012.000000        3.000000          13.000000
# 75%          2017.000000        5.000000          58.000000
# max          2022.000000     1250.000000         607.000000
#
#        reviews per month  review rate number  calculated host listings count  \
# count        8644.000000         9908.000000                     9977.000000
# mean            0.873768            3.011001                        2.555979
# std             1.155960            1.422107                        6.762474
# min             0.010000            1.000000                        1.000000
# 25%             0.110000            2.000000                        1.000000
# 50%             0.370000            3.000000                        1.000000
# 75%             1.200000            4.000000                        2.000000
# max            13.450000            5.000000                      121.000000
#
#        availability 365
# count       9882.000000
# mean         208.068002
# std          125.959305
# min          -10.000000
# 25%           99.000000
# 50%          209.000000
# 75%          317.000000
# max          426.000000

# %%
#df.fillna(0, inplace=True)

df.isnull().sum().sort_values(ascending=False)
# Out:
# last review                       1370
# reviews per month                 1356
# Construction year                  132
# availability 365                   118
# review rate number                  92
# minimum nights                      92
# host_identity_verified              86
# instant_bookable                    67
# cancellation_policy                 41
# service fee                         31
# price                               29
# neighbourhood group                 24
# calculated host listings count      23
# host name                           23
# neighbourhood                       14
# NAME                                12
# number of reviews                   11
# lat                                  8
# long                                 8
# id                                   0
# host id                              0
# room type                            0
# dtype: int64

# %%
df['last review'] = df['last review'].fillna('Unknown')
df['reviews per month'] = df['reviews per month'].fillna(0)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Construction year                 132
# availability 365                  118
# review rate number                 92
# minimum nights                     92
# host_identity_verified             86
# instant_bookable                   67
# cancellation_policy                41
# service fee                        31
# price                              29
# neighbourhood group                24
# calculated host listings count     23
# host name                          23
# neighbourhood                      14
# NAME                               12
# number of reviews                  11
# lat                                 8
# long                                8
# id                                  0
# host id                             0
# room type                           0
# last review                         0
# reviews per month                   0
# dtype: int64

# %%
df['Construction year'] = df['Construction year'].fillna(df['Construction year'].mode()[0])
df['availability 365'] = df['availability 365'].fillna(df['availability 365'].median())
df['review rate number'] = df['review rate number'].fillna(0)
df['minimum nights'] = df['minimum nights'].fillna(df['minimum nights'].median())

# %%
df['neighbourhood'] = df['neighbourhood'].fillna('Unknown')
df['NAME'] = df['NAME'].fillna('Unknown')
df['number of reviews'] = df['number of reviews'].fillna(0)

# Drop lat/long nulls (important for location)
df = df.dropna(subset=['lat', 'long'])

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# service fee                       31
# price                             29
# calculated host listings count    23
# host id                            0
# id                                 0
# NAME                               0
# neighbourhood group                0
# host name                          0
# host_identity_verified             0
# neighbourhood                      0
# instant_bookable                   0
# cancellation_policy                0
# long                               0
# lat                                0
# Construction year                  0
# room type                          0
# number of reviews                  0
# minimum nights                     0
# last review                        0
# reviews per month                  0
# review rate number                 0
# availability 365                   0
# dtype: int64

# %%
# Remove $ and space, then convert to float
df['price'] = df['price'].str.replace(r'[\$, ]', '', regex=True).astype(float)

# Same for 'service fee' if needed
df['service fee'] = df['service fee'].str.replace(r'[\$, ]', '', regex=True).astype(float)

# %%
cat_fill = ['host_identity_verified', 'instant_bookable', 'cancellation_policy', 'neighbourhood group', 'host name']
for col in cat_fill:
    df[col] = df[col].fillna('Unknown')

num_fill = ['service fee', 'price', 'calculated host listings count']
for col in num_fill:
    df[col] = df[col].fillna(df[col].median())

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# id                                0
# NAME                              0
# host id                           0
# host_identity_verified            0
# host name                         0
# neighbourhood group               0
# neighbourhood                     0
# lat                               0
# long                              0
# instant_bookable                  0
# cancellation_policy               0
# room type                         0
# Construction year                 0
# price                             0
# service fee                       0
# minimum nights                    0
# number of reviews                 0
# last review                       0
# reviews per month                 0
# review rate number                0
# calculated host listings count    0
# availability 365                  0
# dtype: int64

# %%
df['total_cost'] = df['price'] + df['service fee']

# %%
df.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                 West Side Retreat  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                Unknown     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long instant_bookable  ...  price service fee  \
# 0  40.64749 -73.97237            False  ...  966.0       193.0
# 1  40.75362 -73.98377            False  ...  142.0        28.0
# 2  40.80902 -73.94190             True  ...  620.0       124.0
# 3  40.68514 -73.95976             True  ...  368.0        74.0
# 4  40.79851 -73.94399            False  ...  204.0        41.0
#
#    minimum nights  number of reviews  last review  reviews per month  \
# 0            10.0                9.0   10/19/2021               0.21
# 1            30.0               45.0    5/21/2022               0.38
# 2             3.0                0.0      Unknown               0.00
# 3            30.0              270.0     5/7/2019               4.64
# 4            10.0                9.0   11/19/2018               0.10
#
#    review rate number calculated host listings count  availability 365  \
# 0                 4.0                            6.0             286.0
# 1                 4.0                            2.0             228.0
# 2                 5.0                            1.0             352.0
# 3                 4.0                            1.0             322.0
# 4                 3.0                            1.0             289.0
#
#    total_cost
# 0      1159.0
# 1       170.0
# 2       744.0
# 3       442.0
# 4       245.0
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (9992, 23)

# %%
df['last review'] = pd.to_datetime(df['last review'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9992 entries, 0 to 9999
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              9992 non-null   int64
#  1   NAME                            9992 non-null   object
#  2   host id                         9992 non-null   int64
#  3   host_identity_verified          9992 non-null   object
#  4   host name                       9992 non-null   object
#  5   neighbourhood group             9992 non-null   object
#  6   neighbourhood                   9992 non-null   object
#  7   lat                             9992 non-null   float64
#  8   long                            9992 non-null   float64
#  9   instant_bookable                9992 non-null   object
#  10  cancellation_policy             9992 non-null   object
#  11  room type                       9992 non-null   object
#  12  Construction year               9992 non-null   float64
#  13  price                           9992 non-null   float64
#  14  service fee                     9992 non-null   float64
#  15  minimum nights                  9992 non-null   float64
#  16  number of reviews               9992 non-null   float64
#  17  last review                     8623 non-null   datetime64[ns]
#  18  reviews per month               9992 non-null   float64
#  19  review rate number              9992 non-null   float64
#  20  calculated host listings count  9992 non-null   float64
#  21  availability 365                9992 non-null   float64
#  22  total_cost                      9992 non-null   float64
# dtypes: datetime64[ns](1), float64(12), int64(2), object(8)
# memory usage: 1.8+ MB

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# last review                       1369
# NAME                                 0
# id                                   0
# host_identity_verified               0
# host name                            0
# neighbourhood group                  0
# host id                              0
# neighbourhood                        0
# lat                                  0
# instant_bookable                     0
# long                                 0
# room type                            0
# Construction year                    0
# price                                0
# cancellation_policy                  0
# service fee                          0
# minimum nights                       0
# number of reviews                    0
# reviews per month                    0
# review rate number                   0
# calculated host listings count       0
# availability 365                     0
# total_cost                           0
# dtype: int64

# %%
df['last review'] = df['last review'].fillna('Unknown')

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# id                                0
# NAME                              0
# host id                           0
# host_identity_verified            0
# host name                         0
# neighbourhood group               0
# neighbourhood                     0
# lat                               0
# long                              0
# instant_bookable                  0
# cancellation_policy               0
# room type                         0
# Construction year                 0
# price                             0
# service fee                       0
# minimum nights                    0
# number of reviews                 0
# last review                       0
# reviews per month                 0
# review rate number                0
# calculated host listings count    0
# availability 365                  0
# total_cost                        0
# dtype: int64

# %%
df.to_csv("Clean_Airbnb_Data.csv", index=False)
